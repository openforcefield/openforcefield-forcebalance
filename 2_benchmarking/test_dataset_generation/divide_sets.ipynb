# %% [markdown]
# # Attempt to split available, suitable QCA datasets into data for benchmarking
#
# Our plan here is to utilize the training molecules, along with information on chemical similarity and parameter coverage, to split the available benchmarking data into:
# 1. Primary benchmark set (a subset of the full) utilizing chemistry similar to what we've fit to
# 2. Full benchmark sets, covering more chemical diversity
#
# In this notebook we are mainly concerned about the filtering procedure to select the primary benchmark set
#
# ## Big picture outline
# 1. Obtain training set data and potential test set data
# 2. Obtain parameter usage statistics for training set data
# 3. Compute chemical graph similarity matrix of all molecules
# 4. Cluster all molecules based on graph similarity using `DBSCAN`
# 5. Pick potential primary set molecules as those which are in clusters with at least one training set molecule.
# 6. Check parameter usage of all potential primary benchmark set molecules; any which use especially unusual parameters get saved for full benchmark set
#
# # Begin
#
# ## Prerequisites:
# - OpenEye toolkits
# - Scikit learn
# - qcportal
# - numpy
# - matplotlib
# - openforcefield
#
# ## Begin by grabbing datasets we fit to from Yudong Qiu's releases
#
# Specifically, we're interested in seeing which molecules are present in those sets.
#
# Slack discussion here: https://openforcefieldgroup.slack.com/archives/C8P8MLALD/p1568325818091700. Script for extracting molecules from a release: https://github.com/lpwgroup/forcebalance-qcarchive/blob/master/analysis_scripts/find_unique_molecule_smiles.py .  Set from most recent release: https://openforcefieldgroup.slack.com/files/U8ZH3MTL2/FNBUUCADB/target_smiles.txt

# %%
# Load molecules used in release-1 fitting
file = open('target_smiles.txt', 'r')
text = file.readlines()
release_smi = [ line.split()[0] for line in text]

# %% [markdown]
# ## Compute parameter usage statistics for training set molecules
#
# Can draw on `openforcefield/utilities/deprecated/convert_frosst/parameter_usage.ipynb`
# Also drawing on `openforcefield/examples/.../inspect_assigned_parameters.ipynb`
#
# **This will take a few minutes or more to run.**

# %%
from openforcefield.topology import Molecule, Topology
from openforcefield.typing.engines.smirnoff import ForceField

# Initialize storage
parameters_by_ID = dict()

# Let's label using our RC force field
forcefield = ForceField('openff_unconstrained-1.0.0-RC1.offxml')

# Loop over smiles
for smi in release_smi:

    # Create a simple molecule from SMILES and turn it into a topology.
    molecule = Molecule.from_smiles(smi, allow_undefined_stereo = True)
    topology = Topology.from_molecules([molecule])

    # Run the molecule labeling
    molecule_force_list = forcefield.label_molecules(topology)

    #print(smi)
    # Print out a formatted description of the parameters applied to this molecule
    for mol_idx, mol_forces in enumerate(molecule_force_list):
        for force_tag, force_dict in mol_forces.items():
            for (atom_indices, parameter) in force_dict.items():
                pid = parameter.id
                if not pid in parameters_by_ID:
                    parameters_by_ID[pid] = set()
                parameters_by_ID[pid].add(smi)

#print(parameters_by_ID)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def make_param_histogram(param_id_counts, param_ids, letter, title):
    # Graph occurrences of bond parameters
    parm_ids = [ pid for pid in param_ids if pid[0]==letter]
    parm_ids.sort()
    counts_parms = [param_id_counts[parm_id] for parm_id in parm_ids]
    split = int(len(parm_ids)/2)
    
    indices = np.arange(len(parm_ids))
    fix, ax = plt.subplots(2,1,figsize=(16,5))
    ax[0].set_yscale('log', nonposy='clip')
    ax[1].set_yscale('log', nonposy='clip')
    
    rects2 = ax[0].bar(indices[0:split], counts_parms[0:split] )
    ax[0].set_ylabel('Count')
    ax[0].set_xticks( indices[0:split])
    ax[0].set_xticklabels( parm_ids[0:split], rotation=-60, ha='left')
    ax[0].set_xlim(indices[0], indices[split])
    plt.yscale('log',nonposy='clip')
    rects2 = ax[1].bar(indices[split:], counts_parms[split:])
    ax[1].set_ylabel('Count')
    ax[1].set_xticks( indices[split:])
    ax[1].set_xticklabels( parm_ids[split:], rotation=-60, ha='left')
    ax[1].set_xlim(indices[split], indices[-1]+1)
    
    ax[0].set_title(title)
    plt.show()

# %%
# Graph parameter usage
param_id_counts = dict()

for pid in parameters_by_ID:
    param_id_counts[pid] = len(parameters_by_ID[pid])

param_ids = param_id_counts.keys()

# Create Histogram for each type of parameter
# VdW
make_param_histogram(param_id_counts, param_ids, 'n', "VdW usage")
# Bonds
make_param_histogram(param_id_counts, param_ids, 'b', "Bond usage")
# Angles
make_param_histogram(param_id_counts, param_ids, 'a', "Angle usage")
# Torsions
make_param_histogram(param_id_counts, param_ids, 't', "Torsion usage")

# %%
# Build set of parameters which occur in less than N molecules
N = 3

rare_params = []
for pid in parameters_by_ID:
    if param_id_counts[pid] < N:
        rare_params.append(pid)
print(rare_params)
print("%s rare parameters out of %s in total" % (len(rare_params), len(param_id_counts)))
# Out:
# ['b27', 'b85', 'b23', 'n10', 'b24', 't83', 'b58', 't114', 'b78', 'b25', 't38', 't34', 't28', 'b28', 't91', 't92', 'b40', 't117', 't105', 't126', 'b46', 't116', 'b66', 't144', 't7', 'b52', 'a34a', 't141', 't63', 't90', 'a37', 't131', 't60', 'a21', 't80', 't79', 't89', 'n5', 'b73', 'b22', 'a29', 't103', 't104', 't125', 'b43', 'b30', 'b31', 't149', 't127', 'b45', 'b71', 't37', 'b61', 't155b', 'b81', 't6', 't8', 'n33', 'b76', 'b51', 't82', 't115', 'b80', 't32']
# 64 rare parameters out of 305 in total

# %% [markdown]
# ## Get available test set molecules
#
# Note that these molecules have protonation states/tautomers enumerated so we probably have excessive representation of some molecules. Will likely want to filter to NOT have large numbers of molecules which differ only by protonation state, and to avoid unusual protonation states.

# %%
import sys
import os
import qcfractal.interface as ptl

from openeye.oechem import *


# Initialize storage for what we find in QCArchive
molecule_smiles = []
current_data_by_smiles = {}


# Initialize client
client = ptl.FractalClient()

# databases we want to search
ds_keys = [['OptimizationDataset', 'OpenFF Discrepancy Benchmark 1'], \
           ['OptimizationDataset', 'Pfizer Discrepancy Optimization Dataset 1'], \
           ['TorsionDriveDataset', 'Pfizer Discrepancy Torsion Dataset 1'], \
           ['OptimizationDataset', 'FDA Optimization Dataset 1'] ]
 
ds_smiles = []
for key in ds_keys:
    print("Loading dataset {:s} {:s} ... \n".format(*key))
    ds = client.get_collection(*key)

    rec_keys = ds.data.records.keys() #Keys look like SMILES but aren't quite

    #Retrieve actual smiles
    for reckey in rec_keys:
        # Retrieve canonical isomeric SMILES
        smi = ds.data.records[reckey].attributes['canonical_isomeric_smiles']
        # Store if not already stored (will occur multiple times because of conformers)
        if not smi in ds_smiles:
            ds_smiles.append(smi)
        
        # Store info on where this came from
        if not smi in current_data_by_smiles:
            current_data_by_smiles[smi] = []
        current_data_by_smiles[smi].append( (key, ds.data.records[reckey].name) )
    
    # Get progress of datasets; some are not complete as of this pass.
    print("   Status of %s:" % ds.name)
    print(ds.status(['default']))
    print("\n")

# This includes multiple conformers of the same molecules
print("Total number of molecules: %s" % len(ds_smiles))
# Out:
# Loading dataset OptimizationDataset OpenFF Discrepancy Benchmark 1 ...
#
#    Status of OpenFF Discrepancy Benchmark 1:
#             default
# COMPLETE      19479
# ERROR           228
# INCOMPLETE        7
#
#
# Loading dataset OptimizationDataset Pfizer Discrepancy Optimization Dataset 1 ...
#
#    Status of Pfizer Discrepancy Optimization Dataset 1:
#           default
# COMPLETE      352
#
#
# Loading dataset TorsionDriveDataset Pfizer Discrepancy Torsion Dataset 1 ...
#
#    Status of Pfizer Discrepancy Torsion Dataset 1:
#             default
# INCOMPLETE      227
#
#
# Loading dataset OptimizationDataset FDA Optimization Dataset 1 ...
#
#    Status of FDA Optimization Dataset 1:
#             default
# COMPLETE       5410
# ERROR           728
# INCOMPLETE      532
#
#
# Total number of molecules: 3871

# %% [markdown]
# ## (To do) Collapse tautomers/protonation states
#
# We would like to ensure we do NOT end up with, say, 100 different tautomers/protonation states of the same molecule comprising the core of our set. Or to put it another way — unless we do some collapsing of states, molecules with multiple protonation state/tautomeric states will be dramatically overrepresented in our benchmarking.
#
# **(Have not done this yet, and may not really need it at this point.)**

# %% [markdown]
# ## Filter test set molecules by similarity to chemistry of training set molecules
#
#
# Here a first pass will use OEGraphSim. Since the code above is not working yet, for now let's just throw together a couple super quick sets of molecules hard-wired into this code.
#
# ### Do a bit more data bookkeeping
#
# How much data do we have at this point?

# %%
print(len(release_smi), len(ds_smiles))
# Out:
# 645 3871

# %% [markdown]
# At one point we had duplicate molecules in the release data. Check if that's the case and, if so, clean it up.
#
# (We do not currently have duplicates because of updates in Yudong's workflow).

# %%
# At one point I saw duplicates coming in from somewhere. Check.
from openeye.oechem import *

#Duplicate SMILES?
for smi in release_smi:
    if release_smi.count(smi)>1: print(release_smi.count(smi), smi)
#Nope

# Same molecule under different SMILES?
canonical_smiles = []
dupes = []
for smi in release_smi:
    mol = OEMol()
    OEParseSmiles(mol, smi)
    new_smi = OECreateIsoSmiString(mol)
    if new_smi in canonical_smiles:
        #print("Duplicate molecule for original SMILES string %s (canonical smiles %s)" % (smi, new_smi))
        dupes.append(smi)
    else:
        canonical_smiles.append(new_smi)
print("There were %s duplicates found." % len(dupes))
# Out:
# There were 0 duplicates found.

# %%
# Deduplicate
release_smi = canonical_smiles
print(len(release_smi))
# Out:
# 645

# %% [markdown]
# ## Use OEGraphSim to make fingerprints for molecules then compute similarity matrix.
#
# First we compute fingerprints for all molecules and store. Then we compute the full similarity matrix.
#
# Graphing will take a minute or so if the full graph is drawn.

# %%
from openeye.oegraphsim import *
from openeye.oechem import *

# Select fingerprint type
# Chris Bayly/Krisztina Boda recommend tree fingerprints with default path length of 4 bonds
fptype = OEFPType_Tree 

# Make fingerprints for both sets
release_set_fp = []
release_set_mols = []
for smi in release_smi:
    mol = OEMol()
    OEParseSmiles(mol, smi)
    fp = OEFingerPrint()
    OEMakeFP(fp, mol, fptype)
    release_set_fp.append(fp)
    release_set_mols.append(mol)
    
ds_set_fp = []
ds_set_mols = []
for smi in ds_smiles:
    mol = OEMol()
    OEParseSmiles(mol, smi)
    fp = OEFingerPrint()
    OEMakeFP(fp, mol, fptype)
    ds_set_fp.append(fp)
    ds_set_mols.append(mol)
    
    
# Compute full similarity matrix by this OEGraphSim
# Let's make it an (N+M)*(N+M) matrix so we have all-by-all similarities.
# Make coverage set be first N, remainder next M
import numpy as np

N = len(release_smi)
M = len(ds_smiles)

t_matrix = np.zeros( (N+M,N+M), np.float)

comparison_fps = release_set_fp + ds_set_fp
comparison_mols = release_set_mols + ds_set_mols

for n in range(N+M):
    for m in range(N+M):
        if n != m: #Make diagonal elements be zero for more convenience
            t_matrix[n,m] = OETanimoto( comparison_fps[n], comparison_fps[m])

import matplotlib.pyplot as plt
# %matplotlib inline

# Plot part of matrix
plt.figure(figsize =(10,10))
plt.imshow(t_matrix, cmap='hot')

# %% [markdown]
# ## Next cluster to find molecules which are "alone"
#
# In general many of our molecules are not super similar to other molecules, which is fine as long as they are built of fragments which are present in other molecules. However, what we are especially interested in is molecules which contain fragments which are not represented anywhere. To do those, we need some kind of clustering. Ideally clustering would be able to recognize how many clusters there are, allow a similarity threshold for clusters, and potentially allow for outliers.
#
# DBSCAN looks interesting as it can find "noise" points which are distant from others, and doesn't take a predefined number of clusters. It also can take a precalculated distance matrix. See https://stackoverflow.com/questions/16246066/clustering-based-on-distance-matrix and https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html. This seems to suit all our needs.
#
# Chris Bayly also suggested HDBSCAN, which I tried. It only has one major knob to twiddle, the `min_cluster_size`, but playing with this and also other minor knobs, there is a strong tendency to put all of the interesting chemistry into one very large cluster and then have some other small clusters which are dominated by enumerated conformers or similar. I am ruling this out for now and sticking with DBSCAN, which allows me to select a maximum distance within any cluster and presents results which are much more useful on this set.

# %%
#Make distance matrix run from 1 being far to 0 being close rather than the opposite (Tanimoto)
dis_matrix = np.ones_like(t_matrix)-t_matrix

from sklearn.cluster import DBSCAN
from sklearn import metrics

# eps: Controls maximum distance between two samples to be considered as in neighborhood of the other.
# min_samples: Minimum number of samples (compounds) near a compound for it to be considered a core point
# Metric: precomputed means use precomputed distance matrix

# I probably actually want to allow SIGNIFICANT difference between compounds, so I have empirically experimented
# with eps values to see what results in sensible clusters. 
# Chris Bayly suggested a value of around 0.25 (1-0.75) is a good starting point.
# Working from there, I assessed cluster size/chemical sensibility by eye as well as number of "noise points"
# and arrived at a value of around 0.5 as yielding reasonable cluster compositions (PDF visualization below)
clustering = DBSCAN(eps=0.5, min_samples = 5, metric="precomputed")

# Fit clustering
db = clustering.fit(dis_matrix)

# Pull labels
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Total number of points: %d' % len(dis_matrix))
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 84
# Total number of points: 4516
# Estimated number of noise points: 2695

# %%
# Determine how many compounds are in each cluster.
# Cluster "-1" is the "outliers"/noise points that are not in clusters.

mols_by_cluster = {}
cluster_nrs = set(labels)

for label in cluster_nrs:
    mols_by_cluster[label] = []
    
    for (idx, thislabel) in enumerate(labels):
        if thislabel==label:
            mols_by_cluster[label].append(comparison_mols[idx])
            
    print("%d molecules in cluster %s" % (len(mols_by_cluster[label]), label))
# Out:
# 131 molecules in cluster 0
# 339 molecules in cluster 1
# 15 molecules in cluster 2
# 8 molecules in cluster 3
# 20 molecules in cluster 4
# 6 molecules in cluster 5
# 9 molecules in cluster 6
# 37 molecules in cluster 7
# 22 molecules in cluster 8
# 6 molecules in cluster 9
# 6 molecules in cluster 10
# 6 molecules in cluster 11
# 7 molecules in cluster 12
# 87 molecules in cluster 13
# 241 molecules in cluster 14
# 19 molecules in cluster 15
# 17 molecules in cluster 16
# 49 molecules in cluster 17
# 79 molecules in cluster 18
# 13 molecules in cluster 19
# 8 molecules in cluster 20
# 16 molecules in cluster 21
# 9 molecules in cluster 22
# 6 molecules in cluster 23
# 14 molecules in cluster 24
# 9 molecules in cluster 25
# 80 molecules in cluster 26
# 5 molecules in cluster 27
# 6 molecules in cluster 28
# 23 molecules in cluster 29
# 6 molecules in cluster 30
# 14 molecules in cluster 31
# 24 molecules in cluster 32
# 12 molecules in cluster 33
# 10 molecules in cluster 34
# 18 molecules in cluster 35
# 6 molecules in cluster 36
# 6 molecules in cluster 37
# 13 molecules in cluster 38
# 29 molecules in cluster 39
# 8 molecules in cluster 40
# 7 molecules in cluster 41
# 12 molecules in cluster 42
# 4 molecules in cluster 43
# 7 molecules in cluster 44
# 6 molecules in cluster 45
# 6 molecules in cluster 46
# 6 molecules in cluster 47
# 11 molecules in cluster 48
# 6 molecules in cluster 49
# 7 molecules in cluster 50
# 7 molecules in cluster 51
# 6 molecules in cluster 52
# 29 molecules in cluster 53
# 6 molecules in cluster 54
# 9 molecules in cluster 55
# 29 molecules in cluster 56
# 24 molecules in cluster 57
# 9 molecules in cluster 58
# 14 molecules in cluster 59
# 10 molecules in cluster 60
# 6 molecules in cluster 61
# 7 molecules in cluster 62
# 6 molecules in cluster 63
# 12 molecules in cluster 64
# 11 molecules in cluster 65
# 6 molecules in cluster 66
# 6 molecules in cluster 67
# 6 molecules in cluster 68
# 6 molecules in cluster 69
# 7 molecules in cluster 70
# 12 molecules in cluster 71
# 6 molecules in cluster 72
# 8 molecules in cluster 73
# 6 molecules in cluster 74
# 8 molecules in cluster 75
# 6 molecules in cluster 76
# 6 molecules in cluster 77
# 6 molecules in cluster 78
# 8 molecules in cluster 79
# 11 molecules in cluster 80
# 4 molecules in cluster 81
# 6 molecules in cluster 82
# 7 molecules in cluster 83
# 2695 molecules in cluster -1

# %%
# Generate PDF files visualizing the contents of all clusters except -1

from openeye import oedepict
import shutil
import os
if os.path.isdir('cluster_pdfs'): shutil.rmtree('cluster_pdfs')
os.mkdir('cluster_pdfs')

for label in mols_by_cluster:
    if label=='-1':
        continue
        
    oemols = [ OEMol(mol) for mol in mols_by_cluster[label]]
    itf = oechem.OEInterface()
    PageByPage = True
    suppress_h = True
    rows = 10
    cols = 6
    ropts = oedepict.OEReportOptions(rows, cols)
    ropts.SetHeaderHeight(25)
    ropts.SetFooterHeight(25)
    ropts.SetCellGap(2)
    ropts.SetPageMargins(10)
    report = oedepict.OEReport(ropts)
    cellwidth, cellheight = report.GetCellWidth(), report.GetCellHeight()
    opts = oedepict.OE2DMolDisplayOptions(cellwidth, cellheight, oedepict.OEScale_Default * 0.5)
    opts.SetAromaticStyle(oedepict.OEAromaticStyle_Circle)
    pen = oedepict.OEPen(oechem.OEBlack, oechem.OEBlack, oedepict.OEFill_On, 1.0)
    opts.SetDefaultBondPen(pen)
    oedepict.OESetup2DMolDisplayOptions(opts, itf)
    for i, mol in enumerate(oemols):
        cell = report.NewCell()
        mol_copy = oechem.OEMol(mol)
        oedepict.OEPrepareDepiction(mol_copy, False, suppress_h)
        disp = oedepict.OE2DMolDisplay(mol_copy, opts)

        oedepict.OERenderMolecule(cell, disp)

    oedepict.OEWriteReport("cluster_pdfs/cluster%s.pdf" % label, report)

# %%
# Figure out which of our clusters don't contain any training set molecules (and which!)

clusters_with_training_mols = []
test_smi = []
for label in cluster_nrs:
    # Get isomeric SMILES strings for molecules in cluster
    cluster_smis = [ OECreateIsoSmiString(mol) for mol in mols_by_cluster[label]]
    
    # Check if these are in training set molecules
    has_training = False
    for smi in cluster_smis:
        if smi in release_smi:
            has_training = True
            tr_smi = smi
            break
    if has_training:
        print("Cluster %s contains training set molecule %s" % (label, tr_smi) )
        clusters_with_training_mols.append(label)
        for smi in cluster_smis:
            if smi not in release_smi and label != -1:
                test_smi.append(smi)
    else:
        print("No training set molecule found for cluster %s." % label)
clusters_with_training_mols.remove(-1) #Remove "outliers" cluster
        
mols_in_tr_set_clusters = 0
for label in clusters_with_training_mols:
    mols_in_tr_set_clusters += len(mols_by_cluster[label])
print("%s molecules in training set clusters" % mols_in_tr_set_clusters)
print("Number of possible benchmark set molecules %s" % len(test_smi))
# Out:
# Cluster 0 contains training set molecule CC(=O)N(C)c1[nH]ccn1
# Cluster 1 contains training set molecule CC(=O)c1c(cccc1F)F
# Cluster 2 contains training set molecule CC1=NCC(=O)Nc2c1cccc2
# Cluster 3 contains training set molecule CC[C@@H]1C[C@@]1(c2ccc(nn2)OC)N
# Cluster 4 contains training set molecule CCc1cccc(=O)[nH]1
# Cluster 5 contains training set molecule CCc1ccccc1C
# Cluster 6 contains training set molecule CN(C)C(=O)c1c(cc[nH]1)Cl
# Cluster 7 contains training set molecule CN(C)c1ccccc1c2ccccn2
# Cluster 8 contains training set molecule CCc1c(cccc1F)C
# Cluster 9 contains training set molecule COc1ccccc1n2cccn2
# Cluster 10 contains training set molecule C[C@@H](c1[nH][nH]c(=O)n1)NC#N
# Cluster 11 contains training set molecule Cc1ccnn1c2c(cccn2)Cl
# Cluster 12 contains training set molecule CC(C)c1ccccc1
# Cluster 13 contains training set molecule Cc1ccccc1[C@@H]2CCCO2
# No training set molecule found for cluster 14.
# No training set molecule found for cluster 15.
# No training set molecule found for cluster 16.
# No training set molecule found for cluster 17.
# No training set molecule found for cluster 18.
# No training set molecule found for cluster 19.
# No training set molecule found for cluster 20.
# No training set molecule found for cluster 21.
# No training set molecule found for cluster 22.
# No training set molecule found for cluster 23.
# No training set molecule found for cluster 24.
# No training set molecule found for cluster 25.
# Cluster 26 contains training set molecule CN1c2ccccc2CCCC1=O
# No training set molecule found for cluster 27.
# No training set molecule found for cluster 28.
# No training set molecule found for cluster 29.
# No training set molecule found for cluster 30.
# No training set molecule found for cluster 31.
# No training set molecule found for cluster 32.
# No training set molecule found for cluster 33.
# No training set molecule found for cluster 34.
# No training set molecule found for cluster 35.
# No training set molecule found for cluster 36.
# No training set molecule found for cluster 37.
# No training set molecule found for cluster 38.
# No training set molecule found for cluster 39.
# No training set molecule found for cluster 40.
# No training set molecule found for cluster 41.
# No training set molecule found for cluster 42.
# No training set molecule found for cluster 43.
# No training set molecule found for cluster 44.
# No training set molecule found for cluster 45.
# No training set molecule found for cluster 46.
# No training set molecule found for cluster 47.
# No training set molecule found for cluster 48.
# No training set molecule found for cluster 49.
# No training set molecule found for cluster 50.
# No training set molecule found for cluster 51.
# No training set molecule found for cluster 52.
# No training set molecule found for cluster 53.
# No training set molecule found for cluster 54.
# No training set molecule found for cluster 55.
# No training set molecule found for cluster 56.
# No training set molecule found for cluster 57.
# No training set molecule found for cluster 58.
# No training set molecule found for cluster 59.
# No training set molecule found for cluster 60.
# No training set molecule found for cluster 61.
# No training set molecule found for cluster 62.
# No training set molecule found for cluster 63.
# No training set molecule found for cluster 64.
# No training set molecule found for cluster 65.
# No training set molecule found for cluster 66.
# No training set molecule found for cluster 67.
# No training set molecule found for cluster 68.
# No training set molecule found for cluster 69.
# No training set molecule found for cluster 70.
# No training set molecule found for cluster 71.
# No training set molecule found for cluster 72.
# No training set molecule found for cluster 73.
# No training set molecule found for cluster 74.
# No training set molecule found for cluster 75.
# No training set molecule found for cluster 76.
# No training set molecule found for cluster 77.
# No training set molecule found for cluster 78.
# No training set molecule found for cluster 79.
# No training set molecule found for cluster 80.
# No training set molecule found for cluster 81.
# No training set molecule found for cluster 82.
# No training set molecule found for cluster 83.
# Cluster -1 contains training set molecule C
# 779 molecules in training set clusters
# Number of possible benchmark set molecules 565

# %% [markdown]
# ## Narrow down the benchmark set molecules
#
# Currently we have a draft set of benchmark set molecules which is manageable/relatively small. However, we haven't checked whether these use any of our rare parameters. Now it's time to compute which parameters they use, and see how many of these are using rare parameters not well represented in our training set. Such molecules may not be good parts of our primary benchmark set.

# %%
#Figure out parameter usage in potential test set molecules.

# Initialize storage
ts_parameters_by_ID = dict()

# Let's label using our RC force field
forcefield = ForceField('openff_unconstrained-1.0.0-RC1.offxml')

# Loop over smiles
for smi in test_smi:

    # Create a simple molecule from SMILES and turn it into a topology.
    molecule = Molecule.from_smiles(smi)
    topology = Topology.from_molecules([molecule])

    # Run the molecule labeling
    molecule_force_list = forcefield.label_molecules(topology)

    #print(smi)
    # Print out a formatted description of the parameters applied to this molecule
    for mol_idx, mol_forces in enumerate(molecule_force_list):
        for force_tag, force_dict in mol_forces.items():
            for (atom_indices, parameter) in force_dict.items():
                pid = parameter.id
                if not pid in ts_parameters_by_ID:
                    ts_parameters_by_ID[pid] = set()
                ts_parameters_by_ID[pid].add(smi)

# %%
# Cross check against our rare parameters list and see which of these use rare parameters

eliminated_mols = set()
elimination_reasons = dict()
for pid in ts_parameters_by_ID:
    if pid in rare_params:
        for smi in ts_parameters_by_ID[pid]:
            eliminated_mols.add(smi)
            #print("Ruled out %s because it utilizes rare parameter %s..." % (smi,pid))
            if not pid in elimination_reasons:
                elimination_reasons[pid] = 0
            elimination_reasons[pid] += 1
            
print("Eliminated %s molecules..." % len(eliminated_mols))
print("Molecules were eliminated because of these parameters:")
print("   parameter ID \t number of times ")
for pid in elimination_reasons:
    print('   %10s \t\t\t %s' % (pid, elimination_reasons[pid]))

# What ARE those parameters which are particularly troubling?

#Try removing these from test set and see what's left
new_test_set = []
for smi in test_smi:
    if not smi in eliminated_mols:
        new_test_set.append(smi)
        
print("%s molecules would remain." % len(new_test_set))
# Out:
# Eliminated 187 molecules...
# Molecules were eliminated because of these parameters:
#    parameter ID 	 number of times
#           b73 			 17
#           b71 			 135
#           b24 			 1
#           b27 			 4
#           b85 			 4
#           b23 			 32
#           n10 			 4
#           t34 			 1
#            n5 			 3
#          t125 			 4
#           a37 			 5
#           b30 			 1
#            t6 			 1
# 378 molecules would remain.

# %% [markdown]
# ### For future reference, print info on which parameters are most problematic

# %%
parameters = forcefield.get_parameter_handler('Bonds').parameters + forcefield.get_parameter_handler('Angles').parameters+forcefield.get_parameter_handler('ProperTorsions').parameters
for parameter in parameters:
    if parameter.id in elimination_reasons:
        print(parameter.id, parameter.smirks, elimination_reasons[parameter.id])
# Out:
# b23 [#6X2:1]-[#6:2] 32
# b24 [#6X2:1]-[#6X4:2] 1
# b27 [#6X2:1]#[#6X2:2] 4
# b30 [#6X2:1]=[#7:2] 1
# b71 [#6:1]-[#35:2] 135
# b73 [#6:1]-[#53:2] 17
# b85 [#6X2:1]-[#1:2] 4
# a37 [#6X3:1]-[#16X2:2]-[#1:3] 5
# t6 [#9:1]-[#6X4:2]-[#6X4:3]-[#9:4] 1
# t34 [#6X4;r3:1]-;@[#6X4;r3:2]-[#6X3:3]~[#6X3:4] 1
# t125 [*:1]-[#7X4,#7X3:2]-[#7X3$(*~[#6X3,#6X2]):3]~[*:4] 4

# %% [markdown]
# ## Generate PDF graphics of proposed sets

# %%
from openeye import oedepict
import shutil
import os
if os.path.isdir('benchmark_set_pdfs'): shutil.rmtree('benchmark_set_pdfs')
os.mkdir('benchmark_set_pdfs')

set_names = ['primary_benchmark', 'full_benchmark']
sets = [ new_test_set, ds_smiles ]

for (name, smiset) in zip(set_names, sets):
    oemols = []
    for smi in smiset:
        mol = OEMol()
        OEParseSmiles(mol, smi)
        oemols.append(mol)
        
    itf = oechem.OEInterface()
    PageByPage = True
    suppress_h = True
    rows = 10
    cols = 6
    ropts = oedepict.OEReportOptions(rows, cols)
    ropts.SetHeaderHeight(25)
    ropts.SetFooterHeight(25)
    ropts.SetCellGap(2)
    ropts.SetPageMargins(10)
    report = oedepict.OEReport(ropts)
    cellwidth, cellheight = report.GetCellWidth(), report.GetCellHeight()
    opts = oedepict.OE2DMolDisplayOptions(cellwidth, cellheight, oedepict.OEScale_Default * 0.5)
    opts.SetAromaticStyle(oedepict.OEAromaticStyle_Circle)
    pen = oedepict.OEPen(oechem.OEBlack, oechem.OEBlack, oedepict.OEFill_On, 1.0)
    opts.SetDefaultBondPen(pen)
    oedepict.OESetup2DMolDisplayOptions(opts, itf)
    for i, mol in enumerate(oemols):
        cell = report.NewCell()
        mol_copy = oechem.OEMol(mol)
        oedepict.OEPrepareDepiction(mol_copy, False, suppress_h)
        disp = oedepict.OE2DMolDisplay(mol_copy, opts)

        oedepict.OERenderMolecule(cell, disp)

    oedepict.OEWriteReport(f"benchmark_set_pdfs/{name}.pdf", report)

# %% [markdown]
# ## Store QCA info to construct datasets containing these molecules
#
# MolSSI will construct new QCA datasets for us containing this data -- specifically, our benchmarking data. These have to be broken out separately by TorsionDriveDataset and OptimizationDataset. So we'll end up with four:
# - Primary benchmark:
#     - Geometry optimization - "OpenFF Primary Optimization Benchmark 1"
#     - Torsion drive - "OpenFF Primary TorsionDrive Benchmark 1"
# - Full benchmark
#     - Geometry optimization - "OpenFF Full Optimization Benchmark 1"
#     - Torsion drive - "OpenFF Full TorsionDrive Benchmark 1"

# %%
# Handle primary benchmark
primary_optimizations = []
primary_torsions = []
for smi in new_test_set:
    # Pull current data details
    for entry in current_data_by_smiles[smi]:
        # Each entry is a tuple of (key, ds.data.records[record key].name)
        set_key, recname = entry
        if set_key[0]=='OptimizationDataset':
            primary_optimizations.append(f"{set_key[0]}, {set_key[1]}, {recname}\n")
        else:
            primary_torsions.append(f"{set_key[0]}, {set_key[1]}, {recname}\n")
            
file = open("primary_optimization_benchmark_1.txt", 'w')
file.writelines(primary_optimizations)
file.close()
file = open("primary_torsiondrive_benchmark_1.txt", 'w')
file.writelines(primary_torsions)
file.close()

# Handle full benchmark
full_optimizations = []
full_torsions = []
for smi in ds_smiles:
    # Pull current data details
    for entry in current_data_by_smiles[smi]:
        # Each entry is a tuple of (key, ds.data.records[record key].name)
        set_key, recname = entry
        if set_key[0]=='OptimizationDataset':
            full_optimizations.append(f"{set_key[0]}, {set_key[1]}, {recname}\n")
        else:
            full_torsions.append(f"{set_key[0]}, {set_key[1]}, {recname}\n")
            
file = open("full_optimization_benchmark_1.txt", 'w')
file.writelines(full_optimizations)
file.close()
file = open("full_torsiondrive_benchmark_1.txt", 'w')
file.writelines(full_torsions)
file.close()

# %% [markdown]
# ## Additional potential data
#
# Perhaps we can also test on the supporting data from Sellers/Gobbi's JCIM paper -- https://pubs.acs.org/doi/abs/10.1021/acs.jcim.6b00614
